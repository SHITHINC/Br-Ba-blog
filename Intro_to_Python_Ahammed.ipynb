# %%
# 📌 Python Basics by Ahammed Shithin C

# 1. Variables
name = "Ahammed"
age = 22
print("Hi, I am", name, "and I am", age, "years old.")
# Out:
# Hi, I am Ahammed and I am 22 years old.

# %%
# 2. List & Loop
languages = ["Python", "SQL", "Dart", "JavaScript"]
for lang in languages:
    print("I can work with:", lang)
# Out:
# I can work with: Python
# I can work with: SQL
# I can work with: Dart
# I can work with: JavaScript

# %%
# 3. Function
def add(a, b):
    return a + b

print("Sum Example:", add(10, 20))
# Out:
# Sum Example: 30

# %%
# 4. Pandas Demo
import pandas as pd
data = {"Item": ["Pen", "Book", "Mouse"], "Stock": [100, 40, 15]}
df = pd.DataFrame(data)
df
# Out:
#     Item  Stock
# 0    Pen    100
# 1   Book     40
# 2  Mouse     15

# %%
# 5. Visualization
import matplotlib.pyplot as plt

plt.bar(df["Item"], df["Stock"])
plt.title("Stock Levels")
plt.xlabel("Item")
plt.ylabel("Quantity")
plt.show()
